# %% [markdown]
# ## Bayesian Neural Network (cc exg ch cv)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### load data

# %%
with open("./data/train_data/grid_cc.npy", "rb") as fin:
    x_train_grid_cc = np.load(fin)

with open("./data/train_data/grid_exg.npy", "rb") as fin:
    x_train_grid_exg = np.load(fin)
    
with open("./data/train_data/grid_ch.npy", "rb") as fin:
    x_train_grid_ch = np.load(fin)
    
with open("./data/train_data/grid_cv.npy", "rb") as fin:
    x_train_grid_cv = np.load(fin)
    
with open("./data/train_data/yield_train.npy", "rb") as fin:
    y_train = np.load(fin)

# %%
print(x_train_grid_cc.shape)
print(x_train_grid_exg.shape)
print(x_train_grid_ch.shape)
print(x_train_grid_cv.shape)
print(y_train.shape)
# Out:
# (7240, 120)
# (7240, 120)
# (7240, 120)
# (7240, 120)
# (7240, 1)

# %%
with open("./data/test_data/grid_cc.npy", "rb") as fin:
    x_testset_cc = np.load(fin)

with open("./data/test_data/grid_exg.npy", "rb") as fin:
    x_testset_exg = np.load(fin)
    
with open("./data/test_data/grid_ch.npy", "rb") as fin:
    x_testset_ch = np.load(fin)
    
with open("./data/test_data/grid_cv.npy", "rb") as fin:
    x_testset_cv = np.load(fin)
    
with open("./data/test_data/yield_test.npy", "rb") as fin:
    y_testset = np.load(fin)

# %%
print(x_testset_cc.shape)
print(x_testset_exg.shape)
print(x_testset_ch.shape)
print(x_testset_cv.shape)
print(y_testset.shape)
# Out:
# (3983, 120)
# (3983, 120)
# (3983, 120)
# (3983, 120)
# (3983, 1)

# %% [markdown]
# #### yield kg/(100m2) => kg/ha

# %%
y_train = y_train / 0.01
y_testset = y_testset / 0.01

# %% [markdown]
# ### train, validation, and test

# %%
from sklearn.model_selection import train_test_split

# %%
def split_train_test(x, y, test_size=0.3):
    x_train, x_valid, y_train, y_valid = train_test_split(
        x, y, test_size=test_size, random_state=42
    )
    x_valid, x_test, y_valid, y_test = train_test_split(
        x_valid, y_valid, test_size=0.5, random_state=43
    )
    return x_train, x_valid, x_test, y_train, y_valid, y_test

# %%
x_train_grid_cc, x_valid_grid_cc, x_test_grid_cc, y_train_grid_cc, y_valid_grid_cc, y_test_grid_cc = split_train_test(x_train_grid_cc, y_train)

# %%
x_train_grid_exg, x_valid_grid_exg, x_test_grid_exg, y_train_grid_exg, y_valid_grid_exg, y_test_grid_exg = split_train_test(x_train_grid_exg, y_train)

# %%
x_train_grid_ch, x_valid_grid_ch, x_test_grid_ch, y_train_grid_ch, y_valid_grid_ch, y_test_grid_ch = split_train_test(x_train_grid_ch, y_train)

# %%
x_train_grid_cv, x_valid_grid_cv, x_test_grid_cv, y_train_grid_cv, y_valid_grid_cv, y_test_grid_cv = split_train_test(x_train_grid_cv, y_train)

# %%
all(y_train_grid_cc == y_train_grid_exg), all(y_train_grid_exg == y_train_grid_ch), all(y_train_grid_ch == y_train_grid_cv)
# Out:
# (True, True, True)

# %%
all(y_valid_grid_cc == y_valid_grid_exg), all(y_valid_grid_exg == y_valid_grid_ch), all(y_valid_grid_ch == y_valid_grid_cv)
# Out:
# (True, True, True)

# %%
all(y_test_grid_cc == y_test_grid_exg), all(y_test_grid_exg == y_test_grid_ch), all(y_test_grid_ch == y_test_grid_cv)
# Out:
# (True, True, True)

# %%
y_train = y_train_grid_cc
y_valid = y_valid_grid_cc
y_test = y_test_grid_cc

# %% [markdown]
# #### metrics

# %%
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr

# %% [markdown]
# #### cc, exg, ch, cv

# %%
x_train_cxhv = np.concatenate(
    [x_train_grid_cc, x_train_grid_exg, x_train_grid_ch, x_train_grid_cv],
    axis=1,
)

x_train_cxhv.shape, y_train.shape
# Out:
# ((5068, 480), torch.Size([5068, 1]))

# %%
x_valid_cxhv = np.concatenate(
    [x_valid_grid_cc, x_valid_grid_exg, x_valid_grid_ch, x_valid_grid_cv],
    axis=1,
)

x_valid_cxhv.shape, y_valid.shape
# Out:
# ((1086, 480), (1086, 1))

# %%
x_test_cxhv = np.concatenate(
    [x_test_grid_cc, x_test_grid_exg, x_test_grid_ch, x_test_grid_cv],
    axis=1,
)

x_test_cxhv.shape, y_test.shape
# Out:
# ((1086, 480), (1086, 1))

# %%
x_testset_cxhv = np.concatenate(
    [x_testset_cc, x_testset_exg, x_testset_ch, x_testset_cv],
    axis=1,
)

x_testset_cxhv.shape, y_testset.shape
# Out:
# ((3983, 480), (3983, 1))

# %% [markdown]
# ### BNN

# %%
import torch
import torch.nn as nn

# %%
import pyro
import pyro.distributions as dist
from pyro.infer import SVI, Trace_ELBO
from pyro.infer.autoguide import AutoDiagonalNormal
from pyro.nn import PyroModule, PyroSample

# %%
x_train_cxhv = torch.from_numpy(x_train_cxhv).to(torch.float32)
y_train = torch.from_numpy(y_train).to(torch.float32)

# %%
class BNN(PyroModule):
    def __init__(self, in_features, out_features):
        super(BNN, self).__init__()
        self.linear_1 = PyroModule[nn.Linear](in_features, 512)
        self.linear_1.weight = PyroSample(
            dist.Normal(0.0, 1.0).expand([512, in_features]).to_event(2)
        )
        self.linear_1.bias = PyroSample(dist.Normal(0.0, 1.0).expand([512]).to_event(1))

        self.linear_2 = PyroModule[nn.Linear](512, 1024)
        self.linear_2.weight = PyroSample(
            dist.Normal(0.0, 1.0).expand([1024, 512]).to_event(2)
        )
        self.linear_2.bias = PyroSample(
            dist.Normal(0.0, 1.0).expand([1024]).to_event(1)
        )

        self.linear_3 = PyroModule[nn.Linear](1024, 256)
        self.linear_3.weight = PyroSample(
            dist.Normal(0.0, 1.0).expand([256, 1024]).to_event(2)
        )
        self.linear_3.bias = PyroSample(dist.Normal(0.0, 1.0).expand([256]).to_event(1))

        self.linear_4 = PyroModule[nn.Linear](256, 1)
        self.linear_4.weight = PyroSample(
            dist.Normal(0.0, 1.0).expand([1, 256]).to_event(2)
        )
        self.linear_4.bias = PyroSample(dist.Normal(0.0, 1.0).expand([1]).to_event(1))
        self.relu = nn.ReLU()

    def forward(self, x, y=None):
        x = self.relu(self.linear_1(x))
        x = self.relu(self.linear_2(x))
        x = self.relu(self.linear_3(x))

        mean = self.linear_4(x).squeeze(-1)
        sigma = pyro.sample("sigma", dist.Uniform(0.0, 10.0))
        with pyro.plate("data", x.shape[0]):
            obs = pyro.sample("obs", dist.Normal(mean, sigma), obs=y)
        return mean

# %%
model = BNN(480, 1)
guide = AutoDiagonalNormal(model)

# %%
adam = pyro.optim.Adam({"lr": 0.03})
svi = SVI(model, guide, adam, loss=Trace_ELBO())

# %%
num_iterations = 20000

# %%
pyro.clear_param_store()

losses = []

for j in range(num_iterations):
    loss = svi.step(x_train_cxhv, y_train.squeeze(-1))
    losses.append(loss)
    
    if j % 100 == 0:
        print("[iteration %04d] loss: %.4f" % (j+1, loss/len(x_train_cxhv)))
# Out:
# [iteration 0001] loss: 711.9458
# [iteration 0101] loss: 711.5465
# [iteration 0201] loss: 896.7233
# [iteration 0301] loss: 1548.7912
# [iteration 0401] loss: 12833.4027
# [iteration 0501] loss: 9230.1257
# [iteration 0601] loss: 14731.4281
# [iteration 0701] loss: 2300.2170
# [iteration 0801] loss: 806.4396
# [iteration 0901] loss: 1163.4164
# [iteration 1001] loss: 981.5747
# [iteration 1101] loss: 731.9320
# [iteration 1201] loss: 966.0453
# [iteration 1301] loss: 1223.9518
# [iteration 1401] loss: 912.8582
# [iteration 1501] loss: 931.5777
# [iteration 1601] loss: 1178.8625
# [iteration 1701] loss: 943.9183
# [iteration 1801] loss: 683.0300
# [iteration 1901] loss: 817.5180
# [iteration 2001] loss: 836.2488
# [iteration 2101] loss: 744.5262
# [iteration 2201] loss: 754.5024
# [iteration 2301] loss: 636.8903
# [iteration 2401] loss: 647.4961
# [iteration 2501] loss: 718.6608
# [iteration 2601] loss: 779.8027
# [iteration 2701] loss: 915.1204
# [iteration 2801] loss: 626.1211
# [iteration 2901] loss: 642.7981
# [iteration 3001] loss: 870.8571
# [iteration 3101] loss: 606.5864
# [iteration 3201] loss: 643.2528
# [iteration 3301] loss: 649.6329
# [iteration 3401] loss: 668.6090
# [iteration 3501] loss: 791.7199
# [iteration 3601] loss: 546.6969
# [iteration 3701] loss: 583.5510
# [iteration 3801] loss: 720.2805
# [iteration 3901] loss: 659.2014
# [iteration 4001] loss: 569.0780
# [iteration 4101] loss: 587.5638
# [iteration 4201] loss: 643.3099
# [iteration 4301] loss: 569.8052
# [iteration 4401] loss: 712.0935
# [iteration 4501] loss: 568.9752
# [iteration 4601] loss: 633.7534
# [iteration 4701] loss: 595.7174
# [iteration 4801] loss: 540.2200
# [iteration 4901] loss: 580.2179
# [iteration 5001] loss: 569.9283
# [iteration 5101] loss: 537.6417
# [iteration 5201] loss: 538.0144
# [iteration 5301] loss: 533.4260
# [iteration 5401] loss: 494.1064
# [iteration 5501] loss: 481.6896
# [iteration 5601] loss: 501.9206
# [iteration 5701] loss: 503.5352
# [iteration 5801] loss: 503.5318
# [iteration 5901] loss: 490.0793
# [iteration 6001] loss: 463.7249
# [iteration 6101] loss: 572.4177
# [iteration 6201] loss: 465.5922
# [iteration 6301] loss: 457.2936
# [iteration 6401] loss: 454.0204
# [iteration 6501] loss: 561.9300
# [iteration 6601] loss: 425.9556
# [iteration 6701] loss: 466.7432
# [iteration 6801] loss: 444.1911
# [iteration 6901] loss: 440.3270
# [iteration 7001] loss: 464.6792
# [iteration 7101] loss: 407.4372
# [iteration 7201] loss: 438.1643
# [iteration 7301] loss: 422.9169
# [iteration 7401] loss: 412.9455
# [iteration 7501] loss: 405.2991
# [iteration 7601] loss: 375.8576
# [iteration 7701] loss: 393.5429
# [iteration 7801] loss: 386.9641
# [iteration 7901] loss: 399.8297
# [iteration 8001] loss: 376.1260
# [iteration 8101] loss: 368.5826
# [iteration 8201] loss: 380.1495
# [iteration 8301] loss: 376.6420
# [iteration 8401] loss: 362.4258
# [iteration 8501] loss: 490.1975
# [iteration 8601] loss: 479.3528
# [iteration 8701] loss: 371.3642
# [iteration 8801] loss: 693.2301
# [iteration 8901] loss: 371.6766
# [iteration 9001] loss: 347.1334
# [iteration 9101] loss: 341.9803
# [iteration 9201] loss: 342.0236
# [iteration 9301] loss: 325.3994
# [iteration 9401] loss: 331.3153
# [iteration 9501] loss: 331.3256
# [iteration 9601] loss: 331.8249
# [iteration 9701] loss: 342.2194
# [iteration 9801] loss: 324.5179
# [iteration 9901] loss: 319.7541
# [iteration 10001] loss: 326.8356
# [iteration 10101] loss: 302.0403
# [iteration 10201] loss: 303.5352
# [iteration 10301] loss: 314.8938
# [iteration 10401] loss: 286.9864
# [iteration 10501] loss: 286.2680
# [iteration 10601] loss: 314.8061
# [iteration 10701] loss: 283.8207
# [iteration 10801] loss: 282.3449
# [iteration 10901] loss: 296.2051
# [iteration 11001] loss: 279.1994
# [iteration 11101] loss: 274.9839
# [iteration 11201] loss: 265.7729
# [iteration 11301] loss: 273.0969
# [iteration 11401] loss: 263.7108
# [iteration 11501] loss: 262.5029
# [iteration 11601] loss: 257.2785
# [iteration 11701] loss: 254.2475
# [iteration 11801] loss: 254.6902
# [iteration 11901] loss: 498.3271
# [iteration 12001] loss: 276.6251
# [iteration 12101] loss: 262.2126
# [iteration 12201] loss: 250.7934
# [iteration 12301] loss: 251.8293
# [iteration 12401] loss: 296.0689
# [iteration 12501] loss: 243.9808
# [iteration 12601] loss: 236.8323
# [iteration 12701] loss: 244.8344
# [iteration 12801] loss: 237.9014
# [iteration 12901] loss: 230.0810
# [iteration 13001] loss: 228.2542
# [iteration 13101] loss: 223.0139
# [iteration 13201] loss: 248.7260
# [iteration 13301] loss: 235.2755
# [iteration 13401] loss: 221.3097
# [iteration 13501] loss: 217.6300
# [iteration 13601] loss: 213.7151
# [iteration 13701] loss: 265.6101
# [iteration 13801] loss: 217.7213
# [iteration 13901] loss: 209.7503
# [iteration 14001] loss: 207.6721
# [iteration 14101] loss: 205.8707
# [iteration 14201] loss: 204.2542
# [iteration 14301] loss: 201.8099
# [iteration 14401] loss: 206.8006
# [iteration 14501] loss: 199.8091
# [iteration 14601] loss: 258.6960
# [iteration 14701] loss: 196.7124
# [iteration 14801] loss: 312.0372
# [iteration 14901] loss: 192.6028
# [iteration 15001] loss: 314.8890
# [iteration 15101] loss: 193.9083
# [iteration 15201] loss: 205.8397
# [iteration 15301] loss: 193.0308
# [iteration 15401] loss: 185.0090
# [iteration 15501] loss: 184.0716
# [iteration 15601] loss: 551.6214
# [iteration 15701] loss: 6438.9806
# [iteration 15801] loss: 4410.7366
# [iteration 15901] loss: 785.7465
# [iteration 16001] loss: 236.4483
# [iteration 16101] loss: 270.8671
# [iteration 16201] loss: 220.3704
# [iteration 16301] loss: 243.6547
# [iteration 16401] loss: 224.4787
# [iteration 16501] loss: 204.5974
# [iteration 16601] loss: 193.3273
# [iteration 16701] loss: 217.1967
# [iteration 16801] loss: 187.1189
# [iteration 16901] loss: 241.7086
# [iteration 17001] loss: 203.8197
# [iteration 17101] loss: 342.2246
# [iteration 17201] loss: 178.8181
# [iteration 17301] loss: 176.7584
# [iteration 17401] loss: 176.7503
# [iteration 17501] loss: 201.1895
# [iteration 17601] loss: 234.2250
# [iteration 17701] loss: 182.3639
# [iteration 17801] loss: 221.8688
# [iteration 17901] loss: 191.0881
# [iteration 18001] loss: 205.7703
# [iteration 18101] loss: 182.0171
# [iteration 18201] loss: 173.3843
# [iteration 18301] loss: 178.8862
# [iteration 18401] loss: 170.0711
# [iteration 18501] loss: 171.1257
# [iteration 18601] loss: 164.5621
# [iteration 18701] loss: 163.0920
# [iteration 18801] loss: 217.4964
# [iteration 18901] loss: 169.6629
# [iteration 19001] loss: 157.8283
# [iteration 19101] loss: 159.8316
# [iteration 19201] loss: 157.4419
# [iteration 19301] loss: 157.4846
# [iteration 19401] loss: 157.5698
# [iteration 19501] loss: 287.6343
# [iteration 19601] loss: 258.6951
# [iteration 19701] loss: 443.6390
# [iteration 19801] loss: 212.6306
# [iteration 19901] loss: 194.3668

# %%
from pyro.infer import Predictive

# %%
def summary(samples):
    site_states = {}

    for k, v in samples.items():
        site_states[k] = {
            "mean": torch.mean(v, 0),
            "std": torch.std(v, 0),
            "5%": v.kthvalue(int(len(v) * 0.05), dim=0)[0],
            "95%": v.kthvalue(int(len(v) * 0.95), dim=0)[0],
        }
    return site_states

# %%
predictive = Predictive(
    model, guide=guide, num_samples=800, return_sites=("linear.weight", "obs", "_RETURN")
)

# %%
x_valid_cxhv = torch.from_numpy(x_valid_cxhv).to(torch.float32)
x_test_cxhv = torch.from_numpy(x_test_cxhv).to(torch.float32)
x_testset_cxhv = torch.from_numpy(x_testset_cxhv).to(torch.float32)

# %%
valid_preds = predictive(x_valid_cxhv)
test_preds = predictive(x_test_cxhv)
cross_year_preds = predictive(x_testset_cxhv)

# %%
valid_pred = valid_preds["_RETURN"].mean(axis=0)
test_pred = test_preds["_RETURN"].mean(axis=0)
cross_year_pred = cross_year_preds["_RETURN"].mean(axis=0)

# %%
print(f"valid rmse:      {np.sqrt(mean_squared_error(y_valid, valid_pred)):.3f}")
print(f"test rmse:       {np.sqrt(mean_squared_error(y_test, test_pred)):.3f}")
print(f"cross year rmse: {np.sqrt(mean_squared_error(y_testset, cross_year_pred)):.3f}")
# Out:
# valid rmse:      199.266
# test rmse:       212.468
# cross year rmse: 139.542

# %%
print(f"valid pearsonr: {pearsonr(np.squeeze(y_valid), valid_pred)[0]:.3f}")
print(f"test pearsonr: {pearsonr(np.squeeze(y_test), test_pred)[0]:.3f}")
print(f"cross year pearsonr: {pearsonr(np.squeeze(y_testset), cross_year_pred)[0]:.3f}")
# Out:
# valid pearsonr: 0.883
# test pearsonr: 0.866
# cross year pearsonr: 0.753

# %%
valid_rmse_p = np.sqrt(mean_squared_error(y_valid, valid_pred)) / np.mean(y_valid)
print(f"valid rmse%      {valid_rmse_p * 100:.2f}%")
test_rmse_p = np.sqrt(mean_squared_error(y_test, test_pred)) / np.mean(y_test)
print(f"test rmse%       {test_rmse_p * 100:.2f}%")
cross_year_rmse_p = np.sqrt(mean_squared_error(y_testset, cross_year_pred)) / np.mean(y_testset)
print(f"cross year rmse% {cross_year_rmse_p * 100:.2f}%")
# Out:
# valid rmse%      10.89%
# test rmse%       11.51%
# cross year rmse% 18.11%

# %%
fig, axes = plt.subplots(ncols=3, figsize=(25, 6))

valid_min = np.min([y_valid.min(), valid_pred.min()])
valid_max = np.max([y_valid.max(), valid_pred.max()])
axes[0].scatter(y_valid, valid_pred, facecolors="none", edgecolors="steelblue");
axes[0].set_xlim([valid_min, valid_max])
axes[0].set_ylim([valid_min, valid_max])
axes[0].set_title("valid dataset", fontsize=18);
axes[0].set_xlabel("acutal values", fontsize=16);
axes[0].set_ylabel("predicted values", fontsize=16);
axes[0].plot([valid_min, valid_max], [valid_min, valid_max], linestyle="--", color="red", alpha=0.3);

test_min = np.min([y_test.min(), test_pred.min()])
test_max = np.max([y_test.max(), test_pred.max()])
axes[1].scatter(y_test, test_pred, facecolors="none", edgecolors="steelblue");
axes[1].set_xlim([test_min, test_max])
axes[1].set_ylim([test_min, test_max])
axes[1].set_title("test dataset", fontsize=18);
axes[1].set_xlabel("acutal values", fontsize=16);
axes[1].set_ylabel("predicted values", fontsize=16);
axes[1].plot([test_min, test_max], [test_min, test_max], linestyle="--", color="red", alpha=0.3);

cross_year_min = np.min([y_testset.min(), cross_year_pred.min()])
cross_year_max = np.max([y_testset.max(), cross_year_pred.max()])
axes[2].scatter(y_testset, cross_year_pred, facecolors="none", edgecolors="steelblue");
axes[2].set_xlim([cross_year_min, cross_year_max])
axes[2].set_ylim([cross_year_min, cross_year_max])
axes[2].set_title("cross year dataset", fontsize=18);
axes[2].set_xlabel("acutal values", fontsize=16);
axes[2].set_ylabel("predicted values", fontsize=16);
axes[2].plot([cross_year_min, cross_year_max], [cross_year_min, cross_year_max], linestyle="--", color="red", alpha=0.3);

# %%
torch.save(model, "saved_model/bnn/cxhv.pt")
